# %% [markdown]
# <a href="https://colab.research.google.com/github/Subho-Halder/Hands_on_python/blob/main/Pokemon_%26_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/pokemon_data.csv')

#print(df.head())

# %%
#print all columns
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#print column [Name] upto 5 rows
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
#print multiple columns
print(df[['Name','Type 1','Type 2']])
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
# print specific row
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
# print multiple  row
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
#print specific element(R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
#loc function to access filter
print(df.loc[df['Type 1']=='Fire'])
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
#itering through data
for index, row in df.iterrows():
  print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#sorting
#df.sort_values('Name')
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#sorting multiple([])
df.sort_values(['Type 1','HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#making new columns
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#drop columns
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#adding new column
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#shifting the new column([])
cols=list(df.columns.values)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
#saving the csv
df.to_csv('modified.csv',index=False)

# %%
#filtering data
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2  Generation  Legendary  \
# 0      1              Bulbasaur  Grass    Poison           1      False
# 1      2                Ivysaur  Grass    Poison           1      False
# 2      3               Venusaur  Grass    Poison           1      False
# 3      3  VenusaurMega Venusaur  Grass    Poison           1      False
# 48    43                 Oddish  Grass    Poison           1      False
# ..   ...                    ...    ...       ...         ...        ...
# 718  650                Chespin  Grass       NaN           6      False
# 719  651              Quilladin  Grass       NaN           6      False
# 720  652             Chesnaught  Grass  Fighting           6      False
# 740  672                 Skiddo  Grass       NaN           6      False
# 741  673                 Gogoat  Grass       NaN           6      False
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1  Type 2  Generation  Legendary  Total  \
# 0      1              Bulbasaur  Grass  Poison           1      False    318
# 1      2                Ivysaur  Grass  Poison           1      False    405
# 2      3               Venusaur  Grass  Poison           1      False    525
# 3      3  VenusaurMega Venusaur  Grass  Poison           1      False    625
# 48    43                 Oddish  Grass  Poison           1      False    320
# 49    44                  Gloom  Grass  Poison           1      False    395
# 50    45              Vileplume  Grass  Poison           1      False    490
# 75    69             Bellsprout  Grass  Poison           1      False    300
# 76    70             Weepinbell  Grass  Poison           1      False    390
# 77    71             Victreebel  Grass  Poison           1      False    490
# 344  315                Roselia  Grass  Poison           3      False    400
# ...

# %%
df.loc[(df['Type 1']=='Grass') | (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1    Type 2  Generation  Legendary  \
# 0      1              Bulbasaur  Grass    Poison           1      False
# 1      2                Ivysaur  Grass    Poison           1      False
# 2      3               Venusaur  Grass    Poison           1      False
# 3      3  VenusaurMega Venusaur  Grass    Poison           1      False
# 16    13                 Weedle    Bug    Poison           1      False
# ..   ...                    ...    ...       ...         ...        ...
# 718  650                Chespin  Grass       NaN           6      False
# 719  651              Quilladin  Grass       NaN           6      False
# 720  652             Chesnaught  Grass  Fighting           6      False
# 740  672                 Skiddo  Grass       NaN           6      False
# 741  673                 Gogoat  Grass       NaN           6      False
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
new_df=df.loc[(df['Type 1']=='Grass') | (df['Type 2']=='Poison')]

# %%
#Reset Index
new_df= new_df.reset_index()
new_df
# Out:
#        #                   Name Type 1    Type 2  Generation  Legendary  \
# 0      1              Bulbasaur  Grass    Poison           1      False
# 1      2                Ivysaur  Grass    Poison           1      False
# 2      3               Venusaur  Grass    Poison           1      False
# 3      3  VenusaurMega Venusaur  Grass    Poison           1      False
# 16    13                 Weedle    Bug    Poison           1      False
# ..   ...                    ...    ...       ...         ...        ...
# 718  650                Chespin  Grass       NaN           6      False
# 719  651              Quilladin  Grass       NaN           6      False
# 720  652             Chesnaught  Grass  Fighting           6      False
# 740  672                 Skiddo  Grass       NaN           6      False
# 741  673                 Gogoat  Grass       NaN           6      False
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
new_df.reset_index(inplace=True)

# %%
new_df
# Out:
#     index    #                   Name Type 1    Type 2  Generation  Legendary  \
# 0       0    1              Bulbasaur  Grass    Poison           1      False
# 1       1    2                Ivysaur  Grass    Poison           1      False
# 2       2    3               Venusaur  Grass    Poison           1      False
# 3       3    3  VenusaurMega Venusaur  Grass    Poison           1      False
# 4      16   13                 Weedle    Bug    Poison           1      False
# ..    ...  ...                    ...    ...       ...         ...        ...
# 84    718  650                Chespin  Grass       NaN           6      False
# 85    719  651              Quilladin  Grass       NaN           6      False
# 86    720  652             Chesnaught  Grass  Fighting           6      False
# 87    740  672                 Skiddo  Grass       NaN           6      False
# 88    741  673                 Gogoat  Grass       NaN           6      False
#
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison           1
# 7      6  CharizardMega Charizard X      Fire    Dragon           1
# 8      6  CharizardMega Charizard Y      Fire    Flying           1
# 12     9    BlastoiseMega Blastoise     Water       NaN           1
# 19    15      BeedrillMega Beedrill       Bug    Poison           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN           1
# 87    80        SlowbroMega Slowbro     Water   Psychic           1
# 102   94          GengarMega Gengar     Ghost    Poison           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN           1
# 137  127          PinsirMega Pinsir       Bug    Flying           1
# 141  130      GyaradosMega Gyarados     Water      Dark           1
# 154  142  AerodactylMega Aerodactyl      Rock    Flying           1
# ...

# %%
#dropping(~)
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Generation  Legendary  Total  \
# 0      1            Bulbasaur    Grass  Poison           1      False    318
# 1      2              Ivysaur    Grass  Poison           1      False    405
# 2      3             Venusaur    Grass  Poison           1      False    525
# 4      4           Charmander     Fire     NaN           1      False    309
# 5      5           Charmeleon     Fire     NaN           1      False    405
# ..   ...                  ...      ...     ...         ...        ...    ...
# 794  718     Zygarde50% Forme   Dragon  Ground           6       True    600
# 795  719              Diancie     Rock   Fairy           6       True    600
# 797  720  HoopaHoopa Confined  Psychic   Ghost           6       True    600
# 798  720   HoopaHoopa Unbound  Psychic    Dark           6       True    680
# 799  721            Volcanion     Fire   Water           6       True    600
#
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('Fire|Grass',flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Generation  Legendary  Total  \
# 0      1              Bulbasaur  Grass  Poison           1      False    318
# 1      2                Ivysaur  Grass  Poison           1      False    405
# 2      3               Venusaur  Grass  Poison           1      False    525
# 3      3  VenusaurMega Venusaur  Grass  Poison           1      False    625
# 4      4             Charmander   Fire     NaN           1      False    309
# ..   ...                    ...    ...     ...         ...        ...    ...
# 735  667                 Litleo   Fire  Normal           6      False    369
# 736  668                 Pyroar   Fire  Normal           6      False    507
# 740  672                 Skiddo  Grass     NaN           6      False    350
# 741  673                 Gogoat  Grass     NaN           6      False    531
# 799  721              Volcanion   Fire   Water           6       True    600
#
# ...

# %%
#filter using regex
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Generation  Legendary  \
# 13    10                 Caterpie       Bug       NaN           1      False
# 20    16                   Pidgey    Normal    Flying           1      False
# 21    17                Pidgeotto    Normal    Flying           1      False
# 22    18                  Pidgeot    Normal    Flying           1      False
# 23    18      PidgeotMega Pidgeot    Normal    Flying           1      False
# 30    25                  Pikachu  Electric       NaN           1      False
# 42    37                   Vulpix      Fire       NaN           1      False
# 76    70               Weepinbell     Grass    Poison           1      False
# 84    78                 Rapidash      Fire       NaN           1      False
# 136  127                   Pinsir       Bug       NaN           1      False
# 137  127        PinsirMega Pinsir       Bug    Flying           1      False
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Generation  Legendary  \
# 20    16               Pidgey    Normal    Flying           1      False
# 21    17            Pidgeotto    Normal    Flying           1      False
# 22    18              Pidgeot    Normal    Flying           1      False
# 23    18  PidgeotMega Pidgeot    Normal    Flying           1      False
# 30    25              Pikachu  Electric       NaN           1      False
# 136  127               Pinsir       Bug       NaN           1      False
# 137  127    PinsirMega Pinsir       Bug    Flying           1      False
# 186  172                Pichu  Electric       NaN           2      False
# 219  204               Pineco       Bug       NaN           2      False
# 239  221            Piloswine       Ice    Ground           2      False
# 438  393               Piplup     Water       NaN           4      False
# 558  499              Pignite      Fire  Fighting           5      False
# ...

# %%
#conditional Changes
df.loc[df['Type 1']=='Fire', 'Type 1']='Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander   Flamer     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion   Flamer   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Type 1']=='Flamer', 'Legendary']=True
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander   Flamer     NaN           1       True
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion   Flamer   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df=pd.read_csv('/content/modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Total']>500, ['Generation', 'Legendary']]= ['Test1', 'Test 2']
df
# Out:
#        #                   Name   Type 1  Type 2 Generation Legendary  Total  \
# 0      1              Bulbasaur    Grass  Poison          1     False    318
# 1      2                Ivysaur    Grass  Poison          1     False    405
# 2      3               Venusaur    Grass  Poison      Test1    Test 2    525
# 3      3  VenusaurMega Venusaur    Grass  Poison      Test1    Test 2    625
# 4      4             Charmander     Fire     NaN          1     False    309
# ..   ...                    ...      ...     ...        ...       ...    ...
# 795  719                Diancie     Rock   Fairy      Test1    Test 2    600
# 796  719    DiancieMega Diancie     Rock   Fairy      Test1    Test 2    700
# 797  720    HoopaHoopa Confined  Psychic   Ghost      Test1    Test 2    600
# 798  720     HoopaHoopa Unbound  Psychic    Dark      Test1    Test 2    680
# 799  721              Volcanion     Fire   Water      Test1    Test 2    600
#
# ...

# %%
df=pd.read_csv('/content/modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
#aggregate Statistics
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #  Generation  Legendary       Total         HP  \
# Type 1
# Steel     442.851852    3.851852   0.148148  487.703704  65.222222
# Rock      392.727273    3.454545   0.090909  453.750000  65.363636
# Dragon    474.375000    3.875000   0.375000  550.531250  83.312500
# Ground    356.281250    3.156250   0.125000  437.500000  73.781250
# Ghost     486.500000    4.187500   0.062500  439.562500  64.437500
# Water     303.089286    2.857143   0.035714  430.455357  72.062500
# Ice       423.541667    3.541667   0.083333  433.458333  72.000000
# Grass     344.871429    3.357143   0.042857  421.142857  67.271429
# Bug       334.492754    3.217391   0.000000  378.927536  56.884058
# Dark      461.354839    4.032258   0.064516  445.741935  66.806452
# Poison    251.785714    2.535714   0.000000  399.142857  67.250000
# Fire      327.403846    3.211538   0.096154  458.076923  69.903846
# Psychic   380.807018    3.385965   0.245614  475.947368  70.631579
# ...

# %%
#aggregate Statistics
df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                    #  Generation  Legendary       Total         HP  \
# Type 1
# Dragon    474.375000    3.875000   0.375000  550.531250  83.312500
# Fighting  363.851852    3.370370   0.000000  416.444444  69.851852
# Ground    356.281250    3.156250   0.125000  437.500000  73.781250
# Rock      392.727273    3.454545   0.090909  453.750000  65.363636
# Steel     442.851852    3.851852   0.148148  487.703704  65.222222
# Dark      461.354839    4.032258   0.064516  445.741935  66.806452
# Fire      327.403846    3.211538   0.096154  458.076923  69.903846
# Flying    677.750000    5.500000   0.500000  485.000000  70.750000
# Poison    251.785714    2.535714   0.000000  399.142857  67.250000
# Water     303.089286    2.857143   0.035714  430.455357  72.062500
# Ghost     486.500000    4.187500   0.062500  439.562500  64.437500
# Normal    319.173469    3.051020   0.020408  401.683673  77.275510
# Grass     344.871429    3.357143   0.042857  421.142857  67.271429
# ...

# %%
#doesn't make sense still for function
df.groupby(['Type 1']).sum()
# Out:
#               #  Generation  Legendary  Total    HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug       23080         222          0  26146  3925    4897     4880     3717
# Dark      14302         125          2  13818  2071    2740     2177     2314
# Dragon    15180         124         12  17617  2666    3588     2764     3099
# Electric  15994         144          4  19510  2631    3040     2917     3961
# Fairy      7642          70          1   7024  1260    1046     1117     1335
# Fighting   9824          91          0  11244  1886    2613     1780     1434
# Fire      17025         167          5  23820  3635    4408     3524     4627
# Flying     2711          22          2   1940   283     315      265      377
# Ghost     15568         134          2  14066  2062    2361     2598     2539
# Grass     24141         235          3  29480  4709    5125     4956     5425
# Ground    11401         101          4  14000  2361    3064     2715     1807
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Generation  Legendary  Total   HP  Attack  \
# Type 1
# Bug        69    69      52          69         69     69   69      69
# Dark       31    31      21          31         31     31   31      31
# Dragon     32    32      21          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Fairy      17    17       2          17         17     17   17      17
# Fighting   27    27       7          27         27     27   27      27
# Fire       52    52      24          52         52     52   52      52
# Flying      4     4       2           4          4      4    4       4
# Ghost      32    32      22          32         32     32   32      32
# Grass      70    70      37          70         70     70   70      70
# Ground     32    32      19          32         32     32   32      32
# Ice        24    24      11          24         24     24   24      24
# ...

# %%
df['Count']=1
df.groupby(['Type 1','Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %%
#working with large data

for df in pd.read_csv('/content/modified.csv',chunksize=5):
    print(df)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65
#    #                       Name Type 1  Type 2  Generation  Legendary  Total  \
# 5  5                 Charmeleon   Fire     NaN           1      False    405
# 6  6                  Charizard   Fire  Flying           1      False    534
# ...
